# %%
import pandas as pd

# %%
data = pd.read_csv('../data/rapido_feature_engineered.csv')
data.head()
# Out:
#    number  is_weekend  is_weekday  is_start_of_week  is_end_of_week  \
# 0   14626        True       False             False           False
# 1   85490        True       False             False           False
# 2    5408        True       False             False           False
# 3   58940        True       False             False           False
# 4    5408        True       False             False           False
#
#    is_wednesday        date  is_holiday
# 0         False  2018-04-07       False
# 1         False  2018-04-07       False
# 2         False  2018-04-07       False
# 3         False  2018-04-07       False
# 4         False  2018-04-07       False

# %% [markdown]
# - target variable is missing

# %% [markdown]
# # 69431

# %%
selected_user = 69431
user = data[data.number == selected_user].reset_index(drop=True)
user.head()
# Out:
#    number  is_weekend  is_weekday  is_start_of_week  is_end_of_week  \
# 0   69431        True       False             False           False
# 1   69431        True       False             False           False
# 2   69431        True       False             False           False
# 3   69431       False        True              True           False
# 4   69431       False        True              True           False
#
#    is_wednesday        date  is_holiday
# 0         False  2018-04-07       False
# 1         False  2018-04-07       False
# 2         False  2018-04-07       False
# 3         False  2018-05-01        True
# 4         False  2018-05-01        True

# %%
user = user.drop_duplicates('date').reset_index(drop=True)

# %%
user.head()
# Out:
#    number  is_weekend  is_weekday  is_start_of_week  is_end_of_week  \
# 0   69431        True       False             False           False
# 1   69431       False        True              True           False
# 2   69431       False        True             False            True
# 3   69431       False        True              True           False
# 4   69431       False        True              True           False
#
#    is_wednesday        date  is_holiday
# 0         False  2018-04-07       False
# 1         False  2018-05-01        True
# 2         False  2018-05-04       False
# 3         False  2018-05-28       False
# 4         False  2018-05-29       False

# %%
user.shape
# Out:
# (236, 8)

# %%
user['booking_class'] = 1

# %%
user.head()
# Out:
#    number  is_weekend  is_weekday  is_start_of_week  is_end_of_week  \
# 0   69431        True       False             False           False
# 1   69431       False        True              True           False
# 2   69431       False        True             False            True
# 3   69431       False        True              True           False
# 4   69431       False        True              True           False
#
#    is_wednesday        date  is_holiday  booking_class
# 0         False  2018-04-07       False              1
# 1         False  2018-05-01        True              1
# 2         False  2018-05-04       False              1
# 3         False  2018-05-28       False              1
# 4         False  2018-05-29       False              1

# %%
user.date.max()
# Out:
# '2019-04-07'

# %%
user.date.min()
# Out:
# '2018-04-07'

# %%
date_range = pd.date_range(user.date.min(), user.date.max())
date_range
# Out:
# DatetimeIndex(['2018-04-07', '2018-04-08', '2018-04-09', '2018-04-10',
#                '2018-04-11', '2018-04-12', '2018-04-13', '2018-04-14',
#                '2018-04-15', '2018-04-16',
#                ...
#                '2019-03-29', '2019-03-30', '2019-03-31', '2019-04-01',
#                '2019-04-02', '2019-04-03', '2019-04-04', '2019-04-05',
#                '2019-04-06', '2019-04-07'],
#               dtype='datetime64[ns]', length=366, freq='D')

# %%
user_missing_data = pd.DataFrame(date_range, columns=['date'])
user_missing_data.head()
# Out:
#         date
# 0 2018-04-07
# 1 2018-04-08
# 2 2018-04-09
# 3 2018-04-10
# 4 2018-04-11

# %%
user_missing_data['booking_class'] = 0
user_missing_data['number'] = selected_user
user_missing_data.head()
# Out:
#         date  booking_class  number
# 0 2018-04-07              0   69431
# 1 2018-04-08              0   69431
# 2 2018-04-09              0   69431
# 3 2018-04-10              0   69431
# 4 2018-04-11              0   69431

# %%
user_missing_data['is_weekend'] = user_missing_data.date.dt.dayofweek.isin([5,6])
user_missing_data['is_weekday'] = ~user_missing_data['is_weekend']
user_missing_data['is_start_of_week'] = user_missing_data.date.dt.dayofweek.isin([0,1])
user_missing_data['is_end_of_week'] = user_missing_data.date.dt.dayofweek.isin([3,4])
user_missing_data['is_wednesday'] = user_missing_data.date.dt.dayofweek.isin([2])

# %%
user_missing_data.head()
# Out:
#         date  booking_class  number  is_weekend  is_weekday  is_start_of_week  \
# 0 2018-04-07              0   69431        True       False             False
# 1 2018-04-08              0   69431        True       False             False
# 2 2018-04-09              0   69431       False        True              True
# 3 2018-04-10              0   69431       False        True              True
# 4 2018-04-11              0   69431       False        True             False
#
#    is_end_of_week  is_wednesday
# 0           False         False
# 1           False         False
# 2           False         False
# 3           False         False
# 4           False          True

# %%
holidays = pd.read_csv('../data/holiday.csv')
holidays.DATE = pd.to_datetime(holidays.DATE)
user_missing_data['is_holiday'] = user_missing_data.date.isin(holidays.DATE)

# %%
user_missing_data.head()
# Out:
#         date  booking_class  number  is_weekend  is_weekday  is_start_of_week  \
# 0 2018-04-07              0   69431        True       False             False
# 1 2018-04-08              0   69431        True       False             False
# 2 2018-04-09              0   69431       False        True              True
# 3 2018-04-10              0   69431       False        True              True
# 4 2018-04-11              0   69431       False        True             False
#
#    is_end_of_week  is_wednesday  is_holiday
# 0           False         False       False
# 1           False         False       False
# 2           False         False       False
# 3           False         False       False
# 4           False          True       False

# %%
user.head()
# Out:
#    number  is_weekend  is_weekday  is_start_of_week  is_end_of_week  \
# 0   69431        True       False             False           False
# 1   69431       False        True              True           False
# 2   69431       False        True             False            True
# 3   69431       False        True              True           False
# 4   69431       False        True              True           False
#
#    is_wednesday        date  is_holiday  booking_class
# 0         False  2018-04-07       False              1
# 1         False  2018-05-01        True              1
# 2         False  2018-05-04       False              1
# 3         False  2018-05-28       False              1
# 4         False  2018-05-29       False              1

# %%
user_missing_data = user_missing_data[~user_missing_data.date.isin(user.date)]
user_missing_data.head()
# Out:
#         date  booking_class  number  is_weekend  is_weekday  is_start_of_week  \
# 1 2018-04-08              0   69431        True       False             False
# 2 2018-04-09              0   69431       False        True              True
# 3 2018-04-10              0   69431       False        True              True
# 4 2018-04-11              0   69431       False        True             False
# 5 2018-04-12              0   69431       False        True             False
#
#    is_end_of_week  is_wednesday  is_holiday
# 1           False         False       False
# 2           False         False       False
# 3           False         False       False
# 4           False          True       False
# 5            True         False       False

# %%
user.dtypes
# Out:
# number               int64
# is_weekend            bool
# is_weekday            bool
# is_start_of_week      bool
# is_end_of_week        bool
# is_wednesday          bool
# date                object
# is_holiday            bool
# booking_class        int64
# dtype: object

# %%
user_missing_data.dtypes
# Out:
# date                datetime64[ns]
# booking_class                int64
# number                       int64
# is_weekend                    bool
# is_weekday                    bool
# is_start_of_week              bool
# is_end_of_week                bool
# is_wednesday                  bool
# is_holiday                    bool
# dtype: object

# %%
user.date = pd.to_datetime(user.date)

# %%
complete_data = pd.merge(user, user_missing_data, how='outer')
complete_data.head()
# Out:
#    number is_weekend is_weekday is_start_of_week is_end_of_week is_wednesday  \
# 0   69431       True      False            False          False        False
# 1   69431      False       True             True          False        False
# 2   69431      False       True            False           True        False
# 3   69431      False       True             True          False        False
# 4   69431      False       True             True          False        False
#
#         date is_holiday  booking_class
# 0 2018-04-07      False              1
# 1 2018-05-01       True              1
# 2 2018-05-04      False              1
# 3 2018-05-28      False              1
# 4 2018-05-29      False              1

# %%
complete_data = complete_data.sort_values('date')
complete_data.head()
# Out:
#      number is_weekend is_weekday is_start_of_week is_end_of_week  \
# 0     69431       True      False            False          False
# 236   69431       True      False            False          False
# 237   69431      False       True             True          False
# 238   69431      False       True             True          False
# 239   69431      False       True            False          False
#
#     is_wednesday       date is_holiday  booking_class
# 0          False 2018-04-07      False              1
# 236        False 2018-04-08      False              0
# 237        False 2018-04-09      False              0
# 238        False 2018-04-10      False              0
# 239         True 2018-04-11      False              0

# %%
complete_data.drop(['number','date'], inplace=True, axis=1)
complete_data.head()
# Out:
#     is_weekend is_weekday is_start_of_week is_end_of_week is_wednesday  \
# 0         True      False            False          False        False
# 236       True      False            False          False        False
# 237      False       True             True          False        False
# 238      False       True             True          False        False
# 239      False       True            False          False         True
#
#     is_holiday  booking_class
# 0        False              1
# 236      False              0
# 237      False              0
# 238      False              0
# 239      False              0

# %% [markdown]
# # todo
#
# - drop number and date
# - write it back to file
# - apply different algorithms what you learnt in ML classes

# %%
model.predict()

date = "January, 15 2020"
